# %%
 from google.colab import drive
 drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 cd 'drive/MyDrive/flacso/social data lab/data'
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/flacso/curso big data ago 2021 sfe + 2do cuat flacso/caso python Terrorismo'
# /content

# %%
import pandas as pd
import seaborn as sns

covid1=pd.read_csv("/content/drive/MyDrive/flacso/social data lab/data/Covid19Casos.csv")

# %%
covid1.head()
# Out:
#    id_evento_caso sexo  ...  residencia_departamento_id ultima_actualizacion
# 0         1000000    M  ...                           0           2021-08-31
# 1        10000000    F  ...                           0           2021-08-31
# 2        10000001    F  ...                         490           2021-08-31
# 3        10000002    F  ...                         427           2021-08-31
# 4        10000003    F  ...                           1           2021-08-31
#
# [5 rows x 25 columns]
